# %% [markdown]
# # **Dependencies**

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import grequests
import os

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

from urllib import parse as url
import threading
import queue
import time
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dasan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Constants

# %%
MAX_YT_SEARCH_RESULTS = 5

API_KEY = 'AIzaSyCqTnKWWl26r2_FbJfUlk4WjaFcvLgivUo'
# API_KEY = 'AIzaSyA4egAlqBItZV-K_2H2wpyUFtI4bh_Dz7g'
ACCESS_TOKEN = 'ya29.a0Ad52N389v24Zohy1pE8uKQsqXm-Zz0S5JDp7Aw1sFAhj3ShjtFi4wLpWwwtGGXGFp7uS9uou3TwXHpFpORv7uFgd3cYfmXFvDq2-myfeqfMJoflE1qp9iw6ZVwGb7FxI_d0RztGPYj6-8XNBpvs5dUjqjD8JPFMtQfAaCgYKAdkSARASFQHGX2MidN2FCOGU0OwYG1CMGrkYMA0170'

API_VERSION = 'v3'
API_NAME = 'youtube'

SCHEME = "https"
NETLOC = f'youtube.googleapis.com/{API_NAME}/{API_VERSION}'
YT_SEARCH_ENDPOINT = "/search"
YT_VIDEOS_ENDPOINT = "/videos"

# %% [markdown]
# # **Utility Functions**

# %% [markdown]
# ## Function to remove any stopwords that might occur in tags

# %%
stop_words = set(stopwords.words(stopwords.fileids()))

def remove_stopword_tags(videos):
    for video in videos:
        if 'video_tags' in video.keys() and video['video_tags'] is not None:
            video['video_tags'] = list(filter(lambda x:x not in stop_words, video['video_tags']))
    return videos

# %% [markdown]
# ## Function to stem the tags to their base/root words

# %%
ps = PorterStemmer()

def stem_tags(videos):
    for video in videos:
        if 'video_tags' in video.keys() and video['video_tags'] is not None:
            video['video_tags'] = [ps.stem(tag) for tag in video['video_tags']]
    return videos

# %% [markdown]
# ## Function to generate a link that will get a **search response** from YouTube Data API

# %%
def prepare_link_for_search_request(region_code, order, channel_id=None, search_query=None): # order : viewCount | date
    params = {
        'type' : 'video',
        'part' : 'id',
        'maxResults' : MAX_YT_SEARCH_RESULTS,
        'order' : order,
        'regionCode' : region_code,
        'key' : API_KEY
    }
    if(channel_id != None):
        params['channelId'] = channel_id
    if(search_query != None):
        params['q'] = search_query

    url_str = url.urlunparse((SCHEME, NETLOC, YT_SEARCH_ENDPOINT, None, url.urlencode(params), None))
    return url_str

# %% [markdown]
# ## Function to generate a link that will get a **list of videos** from YouTube Data API

# %%
def prepare_link_for_video_request(video_ids): 
    params = {
        'part' : ','.join(['snippet', 'id', 'contentDetails']),
        'id' : ','.join(video_ids),
        'key' : API_KEY
    }

    url_str = url.urlunparse((SCHEME, NETLOC, YT_VIDEOS_ENDPOINT, None, url.urlencode(params), None))
    return url_str

# %% [markdown]
# # **Implementations**

# %% [markdown]
# ## Recommendation System Utilities

# %% [markdown]
# ### Recommend videos by **Relevant Tags**

# %%
def get_recommendation_by_tags(watched_tags, result_dict=None) :
    if len(watched_tags) == 0 :
        if result_dict is not None:
            result_dict['TAGS_RES'] = None
        return None

    vectorizer = TfidfVectorizer(max_features=250, stop_words=stopwords.fileids())

    vectorized_tags = vectorizer.fit_transform(watched_tags)
    vectorized_tags_DF = pd.DataFrame(vectorized_tags.toarray(), index=watched_tags, columns=vectorizer.get_feature_names_out())
    vectorized_tags_DF.loc[len(vectorized_tags_DF.index)] = abs(vectorized_tags_DF.sum() - 1)

    sorted_tags = (vectorized_tags_DF.iloc[-1].sort_values(ascending=False))
    reduced_sorted_tags = sorted_tags[0: 10 if len(sorted_tags) > 10 else len(sorted_tags)]

    videos_to_search_by_top_tags = [prepare_link_for_search_request('IN', 'date' if np.random.rand() > 0.5 else 'viewCount', search_query=single_tag) for single_tag in reduced_sorted_tags.index]
    search_results = grequests.map(grequests.get(u) for u in videos_to_search_by_top_tags)

    if ['error'] in [list(response.json().keys()) for response in search_results]:
        if result_dict is not None:
            result_dict['TAGS_RES'] = None
        return None

    items_in_search_response = [x for xs in [response.json()['items'] for response in search_results] for x in xs]
    video_ids = [item['videoId'] for item in [item['id'] for item in items_in_search_response]]

    video_search_results = grequests.map(grequests.get(u) for u in [prepare_link_for_video_request(video_ids)])

    if result_dict is not None:
        result_dict['TAGS_RES'] = video_search_results[0].json()['items']
    return video_search_results[0].json()['items']

# %% [markdown]
# ### Recommend videos by **Relevant Topics**

# %%
def get_recommendation_by_topics(watched_topics, result_dict=None) :
    if len(watched_topics) == 0 :
        if result_dict is not None:
            result_dict['TOPICS_RES'] = None
        return None

    vectorizer = TfidfVectorizer(max_features=250, stop_words=stopwords.fileids())

    vectorized_tags = vectorizer.fit_transform(watched_topics)
    vectorized_tags_DF = pd.DataFrame(vectorized_tags.toarray(), index=watched_topics, columns=vectorizer.get_feature_names_out())
    vectorized_tags_DF.loc[len(vectorized_tags_DF.index)] = abs(vectorized_tags_DF.sum() - 1)

    sorted_tags = (vectorized_tags_DF.iloc[-1].sort_values(ascending=False))
    reduced_sorted_tags = sorted_tags[0: 10 if len(sorted_tags) > 10 else len(sorted_tags)]

    videos_to_search_by_top_tags = [prepare_link_for_search_request('IN', 'date' if np.random.rand() > 0.5 else 'viewCount', search_query=single_tag) for single_tag in reduced_sorted_tags.index]
    search_results = grequests.map(grequests.get(u) for u in videos_to_search_by_top_tags)
    
    if ['error'] in [list(response.json().keys()) for response in search_results]:
        if result_dict is not None:
            result_dict['TOPICS_RES'] = None
        return None

    items_in_search_response = [x for xs in [response.json()['items'] for response in search_results] for x in xs]
    video_ids = [item['videoId'] for item in [item['id'] for item in items_in_search_response]]

    video_search_results = grequests.map(grequests.get(u) for u in [prepare_link_for_video_request(video_ids)])

    if result_dict is not None:
        result_dict['TOPICS_RES'] = video_search_results[0].json()['items']
    return video_search_results[0].json()['items']

# %% [markdown]
# ### Recommend videos by **Relevant Channels**

# %%
def get_recommendation_by_channel_ids(watched_channel_ids, result_dict=None) :
    if len(watched_channel_ids) == 0 :
        if result_dict is not None:
            result_dict['CHANNELS_RES'] = None
        return None

    vectorizer = CountVectorizer(max_features=250, stop_words=stopwords.fileids())

    vectorized_channels = vectorizer.fit_transform(watched_channel_ids)
    vectorized_channels_DF = pd.DataFrame(vectorized_channels.toarray(), index=watched_channel_ids, columns=vectorizer.get_feature_names_out())
    vectorized_channels_DF.loc[len(vectorized_channels_DF.index)] = abs(vectorized_channels_DF.sum() - 1)

    sorted_channels = (vectorized_channels_DF.iloc[-1].sort_values(ascending=False))
    reduced_sorted_channels = sorted_channels[0: 10 if len(sorted_channels) > 10 else len(sorted_channels)]

    videos_to_search_by_top_tags = [prepare_link_for_search_request('IN', 'date' if np.random.rand() > 0.5 else 'viewCount', channel_id=single_channel) for single_channel in reduced_sorted_channels.index]
    search_results = grequests.map(grequests.get(u) for u in videos_to_search_by_top_tags)

    if ['error'] in [list(response.json().keys()) for response in search_results]:
        if result_dict is not None:
            result_dict['CHANNELS_RES'] = None
        return None

    items_in_search_response = [x for xs in [response.json()['items'] for response in search_results] for x in xs]
    video_ids = [item['videoId'] for item in [item['id'] for item in items_in_search_response]]

    video_search_results = grequests.map(grequests.get(u) for u in [prepare_link_for_video_request(video_ids)])

    if result_dict is not None:
        result_dict['CHANNELS_RES'] = video_search_results[0].json()['items']
    return video_search_results[0].json()['items']

# %% [markdown]
# ## Recommendation System

# %%
def get_recommendations(watched_channel_ids, watched_topics, watched_tags):

    result = {}

    channel_thread = threading.Thread(name='channel_thread', target=get_recommendation_by_channel_ids, args=(watched_channel_ids, result, ))
    tags_thread = threading.Thread(name='tags_thread', target=get_recommendation_by_tags, args=(watched_tags, result, ))
    topics_thread = threading.Thread(name='topics_thread', target=get_recommendation_by_topics, args=(watched_topics, result, ))

    channel_thread.start()
    tags_thread.start()
    topics_thread.start()

    channel_thread.join()
    tags_thread.join()
    topics_thread.join()

    videos = []
    if result['CHANNELS_RES'] is not None :
        videos = videos + result['CHANNELS_RES']
    if result['TAGS_RES'] is not None :
        videos = videos + result['TAGS_RES']
    if result['TOPICS_RES'] is not None :
        videos = videos + result['TOPICS_RES']

    return {'videos' : videos,
            'videos_by_channel_id' : result['CHANNELS_RES'],
            'videos_by_top_tags' : result['TAGS_RES'],
            'videos_by_top_topics' : result['TOPICS_RES']
            }

# %%
tags = ['gamers',
   'vctth',
   'valorant',
   'vct',
   'vct masters',
   'xerxia',
   'sScary',
   'foxz',
   'Sushiboys',
   'Crws',
   'Surf',
   'Zeus',
   'XIA',
   'BLEED',
   'Esports',
   'Pro player',
   'วาโลแรนต์',
   'crazyguy',
   'Deryeon',
   'Juicy',
   'LEGIJA',
   'Bleed',
   'Aim',
   'routine',
   'games',
   'valorant moment',
   'MickiePP',
   'Superbuss',
   'Boomburapa',
   'Viperdemon',
   'Mith',
   'nephh',
   'Fullsense',
    'yourenotjustin',
   'Justin',
   'valorant',
   'overdrive bundle',
   'what does overdrive bundle have',
   'what skins are in overdrive bundle',
   'overdrive',
   'when does overdrive come out',
   'overdrive reveal valorant',
   'new skins valorant',
   'overdrive price valorant',
   'how much is overdrive valorant',
   'when does overdrive valorant',
   'valorant update',
   'is overdrive bundle worth it',
   'all upgrades',
   'valorant overdrive phantom',
   'overdrive blade',
   'overdrive bundle showcase',
   'review',
   'overdrive sheriff',
   'upgraded',
   'overdrive',
   'valorant overdrive vandal',
   'valorant skins',
   'valorant new skin bundle',
   'bundle overdrive',
   'overdrive katana',
   'overdrive knife',
   'valorant katana',
   'valorant skin bundle',
   'valorant new',
   'valorant new skins',
   'valorant new aimbot',
   'valorant aimbot skin',
   'valorant points',
   'free valorant skins',
   'valorant points free',
   'valorant',
   'dark and darker is better game',
   'valorant overdrive skin',
   'valorant overdrive gameplay',
   'valorant gameplay',
   'valorant yoru',
   'valorant aimbot',
   'valorant',
   'valorant highlights',
   'horcus',
   'gaming',
   'radiant',
   'vlorant',
   'valorant live',
   'live valorant',
   'valorant español',
   'vvalorant',
   'alorant',
   'vaorant',
   'valorat',
   'valorant españa',
   'valorant latam',
   'valornt',
   'valoant',
   'valorant gameplay',
   'valorant competir',
   'competir valorant',
   'competir en valorant',
   'competitivo valorant',
   'valorant competitivo',
   'no competir en valorant',
   'nunca valorant',
   'valorant nunca',
   'compito valorant',
   'compito en valorant',
   'valorant compito',
   'no competir valorant',
   'valorant no competir']
topics = ['Action_game',
   'Role-playing_video_game',
   'Video_game_culture','Action_game',
   'Strategy_video_game',
   'Video_game_culture','Action_game',
   'Role-playing_video_game',
   'Video_game_culture']
channelIDs = ['abc0',
   'abc1',
   'abc2','abc11',
   'abc3',
   'abc4','abc6','abc5',
   'abc5',
   'abc6',
   'abc7','abc11','abc0',
   'abc8',
   'abc9',
   'abc10','abc6','abc6','abc6','abc6','abc0',
   'abc11',
   'abc12','abc11','abc0',
   'abc13','abc0',
   'abc14','abc6','abc5','abc0',
   'abc15',
   'abc16',
   'abc17','abc11',
   'abc18',
   'abc19']

start_time = time.time()
videos = get_recommendations([], topics, tags)
print('Exceution Time:', (time.time() - start_time))
# Out:
# Exceution Time: 5.821445941925049
# c:\Python312\Lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
videos
# Out:
# {'videos': [{'kind': 'youtube#video',
#    'etag': 'ZLk5x92S1lty0_JEK_4FmC2ghWs',
#    'id': 'AzjpMbFvJpA',
#    'snippet': {'publishedAt': '2024-03-12T17:12:27Z',
#     'channelId': 'UCCuzDCoI3EUOo_nhCj4noSw',
#     'title': 'VALORANT NIGHTO WIT JOT, GURAISU, DANAN!@#$%^',
#     'description': "Sociabuzz: https://sociabuzz.com/ybrap\nSaweria:https://saweria.co/yb\n\nI'm still alive.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AzjpMbFvJpA/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AzjpMbFvJpA/mqdefault_live.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AzjpMbFvJpA/hqdefault_live.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/AzjpMbFvJpA/sddefault_live.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/AzjpMbFvJpA/maxresdefault_live.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'yb',
#     'categoryId': '20',
#     'liveBroadcastContent': 'live',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'VALORANT NIGHTO WIT JOT, GURAISU, DANAN!@#$%^',
#      'description': "Sociabuzz: https://sociabuzz.com/ybrap\nSaweria:https://saweria.co/yb\n\nI'm still alive."},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'P0D',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'p3v23inYJs2JpdCnluhEvvu1NcY',
#    'id': '0u3Lhhg4A-0',
#    'snippet': {'publishedAt': '2024-03-12T15:11:26Z',
#     'channelId': 'UCcr4x4DBzRD0871Vq9QyyaA',
#     'title': '2024 VCT Challengers Vietnam Split 1 - CHUNG KẾT NHÁNH THUA - Ngày 11',
#     'description': 'VCT Challengers Vietnam là giải đấu Esports cấp độ cao nhất của VALORANT tại Việt Nam do NPH VNG tổ chức. \n\nGiai đoạn đầu tiên của mùa giải sẽ chính thức khởi tranh từ ngày 15/02/2024 với 08 đội tuyển tham dự, bao gồm:\n- FANCY UNITED ESPORTS\n- FPT FLASH\n- RAPID LOFI\n- DOMINUS ESPORTS\n- TÀN DƯ ESPORTS\n- CROCODILE TEARS\n- LAZY LFO\n- KOBIET\n\nTổng giá trị của giải đấu sẽ vượt trên 500 triệu đồng, hãy sẵn sàng để theo dõi những diễn biến hấp dẫn nhất của mùa giải năm nay.\n\n#VCTChallengers #VCTVN #CăngBuồm\n-----------------------\nVALORANT Champions Tour Vietnam là kênh Youtube chính thức về Esports của game VALORANT tại thị trường Việt Nam. Nơi cập nhật các thông tin liên quan đến Esports, đồng thời là đơn vị duy nhất giữ bản quyền sản xuất toàn bộ nội dung giải đấu VALORANT tại Việt Nam.\nXem thêm thông tin và tải game tại: https://valorant.zing.vn/vi-vn/\n-----------------------\nĐăng kí ngay các kênh mạng xã hội VALORANT Esports Việt Nam để cập nhật những thông tin mới nhất:\n► Fanpage: https://www.facebook.com/ValorantEsportsVietnam\n► YouTube: https://www.youtube.com/ValorantChampionsTourVietnam',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0u3Lhhg4A-0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0u3Lhhg4A-0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0u3Lhhg4A-0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/0u3Lhhg4A-0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/0u3Lhhg4A-0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'VALORANT Champions Tour Vietnam',
#     'tags': ['esports',
#      'valorant',
#      'valorant esports',
#      'valorant esports vietnam',
#      'valorant challengers',
#      'val esports vn',
#      'challengers',
#      'valorant vietnam',
#      'giai dau valorant',
#      'giải đấu esports',
#      'fancy united',
#      'vct challengers vietnam',
#      'vct split 1',
#      'vct vietnam split 1',
#      'cang buom',
#      'rapid lofi',
#      'dominus esports',
#      'team flash',
#      'team flash valorant',
#      'big baam',
#      'highlights valorant',
#      'valorant tournament',
#      'valorant vietnam tournament',
#      'giai dau vct'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '2024 VCT Challengers Vietnam Split 1 - CHUNG KẾT NHÁNH THUA - Ngày 11',
#      'description': 'VCT Challengers Vietnam là giải đấu Esports cấp độ cao nhất của VALORANT tại Việt Nam do NPH VNG tổ chức. \n\nGiai đoạn đầu tiên của mùa giải sẽ chính thức khởi tranh từ ngày 15/02/2024 với 08 đội tuyển tham dự, bao gồm:\n- FANCY UNITED ESPORTS\n- FPT FLASH\n- RAPID LOFI\n- DOMINUS ESPORTS\n- TÀN DƯ ESPORTS\n- CROCODILE TEARS\n- LAZY LFO\n- KOBIET\n\nTổng giá trị của giải đấu sẽ vượt trên 500 triệu đồng, hãy sẵn sàng để theo dõi những diễn biến hấp dẫn nhất của mùa giải năm nay.\n\n#VCTChallengers #VCTVN #CăngBuồm\n-----------------------\nVALORANT Champions Tour Vietnam là kênh Youtube chính thức về Esports của game VALORANT tại thị trường Việt Nam. Nơi cập nhật các thông tin liên quan đến Esports, đồng thời là đơn vị duy nhất giữ bản quyền sản xuất toàn bộ nội dung giải đấu VALORANT tại Việt Nam.\nXem thêm thông tin và tải game tại: https://valorant.zing.vn/vi-vn/\n-----------------------\nĐăng kí ngay các kênh mạng xã hội VALORANT Esports Việt Nam để cập nhật những thông tin mới nhất:\n► Fanpage: https://www.facebook.com/ValorantEsportsVietnam\n► YouTube: https://www.youtube.com/ValorantChampionsTourVietnam'}},
#    'contentDetails': {'duration': 'PT5H49M19S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 't5khJ9kqbgnAfBXl-nC9OT_3N1c',
#    'id': 'lHbuLr4d_6o',
#    'snippet': {'publishedAt': '2024-03-12T15:07:50Z',
#     'channelId': 'UCAr4U_HGMYXn1EZjdWiGSLQ',
#     'title': '【🔴Valorant】ที่ใดมีวาโร ที่นั่นมีผม《 Baabel 》',
#     'description': '💸ค่าทำนุบำรุงลัทธิ💸\nhttps://tipme.in.th/baabel-arp\n\nกฏการดูไลฟ์สตรีม\n- ไม่แสปมข้อความ/อีโมจิซ้ำๆ\n- ไม่พูดคุยประเด็นที่ไม่เกี่ยวข้องกับสตรีมนั้นๆ\n- ไม่กล่าวถึงวีทูบเบอร์/สตรีมเมอร์/บุคคลท่านอื่นที่ถ้าวีไม่ได้กล่าวถึงก่อน\n- ไม่สปอยล์เนื้อหาของเกมถ้าวีไม่ได้ขอความช่วยเหลือ\n- ไม่กล่าวถึง/บอกรักวีในไลฟ์ของวีท่านอื่นถ้าวีไม่ได้ไลฟ์กับวีท่านนั้น\n- ให้เกียรติวีและช่องแชทคนอื่นๆและพูดคุยกันอย่างมีมารยาท\n\nCommunity Rules \n- Avoid spamming/trolling or you may be timed out\n- Please keep conversation relevant to the stream \n- Do not mention other streamers/vtubers unless I bring them up first or you will be timed-out/banned\n- Avoid spoiling game-play unless I ask for help\n- Do not mention me in other Vtuber stream unless I am relevant to the content of that stream.\n- Be respectful to me and other viewers\n\nLoading : Muk @/KingIDark @/nnattos\nhttps://twitter.com/KingIDark/status/1741096914295357443\nSpecial Thanks : @/T2a7o @/meowmeowchan666 @/narunocloud @/tinysaltdaisy @/KingDark @/nnattos\n\n\n#arproject\n\nGeneral #BaabelLamb\nLive Tag #BaabelLive \nArt Tag #BaabelArt\nSinging Tag #BaabelSing\n\n__\n\nFollow us\n\n「 Algorhythm Project 」\nOfficial Website : https://algorhythm.realic.net/\nFacebook: https://www.facebook.com/ARP.Vtuber\nYouTube: https://bit.ly/3ue2Gg8\n\n-------------------------------',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lHbuLr4d_6o/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lHbuLr4d_6o/mqdefault_live.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lHbuLr4d_6o/hqdefault_live.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/lHbuLr4d_6o/sddefault_live.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/lHbuLr4d_6o/maxresdefault_live.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Baabel Ch.【ARP】',
#     'categoryId': '22',
#     'liveBroadcastContent': 'live',
#     'localized': {'title': '【🔴Valorant】ที่ใดมีวาโร ที่นั่นมีผม《 Baabel 》',
#      'description': '💸ค่าทำนุบำรุงลัทธิ💸\nhttps://tipme.in.th/baabel-arp\n\nกฏการดูไลฟ์สตรีม\n- ไม่แสปมข้อความ/อีโมจิซ้ำๆ\n- ไม่พูดคุยประเด็นที่ไม่เกี่ยวข้องกับสตรีมนั้นๆ\n- ไม่กล่าวถึงวีทูบเบอร์/สตรีมเมอร์/บุคคลท่านอื่นที่ถ้าวีไม่ได้กล่าวถึงก่อน\n- ไม่สปอยล์เนื้อหาของเกมถ้าวีไม่ได้ขอความช่วยเหลือ\n- ไม่กล่าวถึง/บอกรักวีในไลฟ์ของวีท่านอื่นถ้าวีไม่ได้ไลฟ์กับวีท่านนั้น\n- ให้เกียรติวีและช่องแชทคนอื่นๆและพูดคุยกันอย่างมีมารยาท\n\nCommunity Rules \n- Avoid spamming/trolling or you may be timed out\n- Please keep conversation relevant to the stream \n- Do not mention other streamers/vtubers unless I bring them up first or you will be timed-out/banned\n- Avoid spoiling game-play unless I ask for help\n- Do not mention me in other Vtuber stream unless I am relevant to the content of that stream.\n- Be respectful to me and other viewers\n\nLoading : Muk @/KingIDark @/nnattos\nhttps://twitter.com/KingIDark/status/1741096914295357443\nSpecial Thanks : @/T2a7o @/meowmeowchan666 @/narunocloud @/tinysaltdaisy @/KingDark @/nnattos\n\n\n#arproject\n\nGeneral #BaabelLamb\nLive Tag #BaabelLive \nArt Tag #BaabelArt\nSinging Tag #BaabelSing\n\n__\n\nFollow us\n\n「 Algorhythm Project 」\nOfficial Website : https://algorhythm.realic.net/\nFacebook: https://www.facebook.com/ARP.Vtuber\nYouTube: https://bit.ly/3ue2Gg8\n\n-------------------------------'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'P0D',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'B3NCWUM3P9xoIlG1k4N8GbbN89U',
#    'id': '1McluNHKyCo',
#    'snippet': {'publishedAt': '2024-03-12T15:03:18Z',
#     'channelId': 'UCq2f2CXdCL7A0tGQ_yiDQlA',
#     'title': 'RANK PUSH VALORANT LIVE',
#     'description': "#tbone #valorant #valorantindia \n💲 UPI: tbonegamng@oksbi \n📷 Instagram • https://www.instagram.com/tbonegaming\n🕊️ Twitter • https://twitter.com/tbonegamng\n\n💻ASUS ROG\n►ROG is the World’s Premium Gaming Laptop Brand,\nTo know More : https://rog.asus.com/in/laptops-group\n\n🖥️ PC Specs\n•AMD Ryzen9 5900X\n•ZOTAC GeForce 4090\n•MSI X570 ACE\n•GSKILL 32GB DDR4\n•Samsung SSD 1TB WD M2 1TB\n•ASUS 360HZ Esports monitor\n•Sony DSLR A6600 (sigma 16 lens) with cam link\n•G733 Wireless Viper V3 pro Wireless G640 Mousepad\n\n🖥️ Streaming PC specs\n•ASRock Z370 Taichi\n•Cooler Master V1000 Fully Modular 80 PLUS Gold\n•ADATA XPG D40 DDR4 RGB 3200MHz (8*4) •Phanteks Enthoo Evolv ATX - Silver\n•Samsung 970 Evo Series 250GB PCIE NVME - M.2\n•Seagate 2TB Firecuda •Cooler Master MasterLiquid ML240R All-in-one\n•ZOTAC GeForce RTX 3080\n•Capture card: Elgato HD60\n\n💰 Benefits Of Being A Sponsor 💰\n\n• Get's a custom badge & Emoji's \n• Access to member only streams. \n• Participate in Sponsor's only Giveaway's.\n• The OnlyFrands Sponsor will have access to exclusive whats app group\n\nAbout TbOne 👦🏻\n\n• Shobith Rai\n• 32\n• Bangalore, India",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1McluNHKyCo/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1McluNHKyCo/mqdefault_live.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1McluNHKyCo/hqdefault_live.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/1McluNHKyCo/sddefault_live.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/1McluNHKyCo/maxresdefault_live.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'TbOne',
#     'tags': ['tbone valorant',
#      'tbone valorant highlights',
#      'tbone live',
#      'tbone funny live',
#      'valorant',
#      'valorant highlights',
#      'valorant india',
#      'tbone',
#      'tbone and fa2',
#      'tbone funny moments',
#      'tbone with fa2',
#      'tbone fa2',
#      'fa2 and tbone backchodi',
#      'tbone csgo',
#      'tbone funny',
#      'tbone gaming',
#      'tbone funny clips',
#      'tbone highlights',
#      'tbone csgo funny',
#      'tbone india',
#      'daily dose of tbone',
#      'tbone stream',
#      'tbone fa2 stream',
#      'tbone funny india',
#      'tbone funny stream',
#      'tbone funny videos',
#      'daily dosage of tbone'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'live',
#     'localized': {'title': 'RANK PUSH VALORANT LIVE',
#      'description': "#tbone #valorant #valorantindia \n💲 UPI: tbonegamng@oksbi \n📷 Instagram • https://www.instagram.com/tbonegaming\n🕊️ Twitter • https://twitter.com/tbonegamng\n\n💻ASUS ROG\n►ROG is the World’s Premium Gaming Laptop Brand,\nTo know More : https://rog.asus.com/in/laptops-group\n\n🖥️ PC Specs\n•AMD Ryzen9 5900X\n•ZOTAC GeForce 4090\n•MSI X570 ACE\n•GSKILL 32GB DDR4\n•Samsung SSD 1TB WD M2 1TB\n•ASUS 360HZ Esports monitor\n•Sony DSLR A6600 (sigma 16 lens) with cam link\n•G733 Wireless Viper V3 pro Wireless G640 Mousepad\n\n🖥️ Streaming PC specs\n•ASRock Z370 Taichi\n•Cooler Master V1000 Fully Modular 80 PLUS Gold\n•ADATA XPG D40 DDR4 RGB 3200MHz (8*4) •Phanteks Enthoo Evolv ATX - Silver\n•Samsung 970 Evo Series 250GB PCIE NVME - M.2\n•Seagate 2TB Firecuda •Cooler Master MasterLiquid ML240R All-in-one\n•ZOTAC GeForce RTX 3080\n•Capture card: Elgato HD60\n\n💰 Benefits Of Being A Sponsor 💰\n\n• Get's a custom badge & Emoji's \n• Access to member only streams. \n• Participate in Sponsor's only Giveaway's.\n• The OnlyFrands Sponsor will have access to exclusive whats app group\n\nAbout TbOne 👦🏻\n\n• Shobith Rai\n• 32\n• Bangalore, India"},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'P0D',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '-qIlyXgO3MDVu3ADoxAcnGYJBCw',
#    'id': 'Fgu5K2IfvRU',
#    'snippet': {'publishedAt': '2024-03-12T15:00:19Z',
#     'channelId': 'UCLU3hJryCoNpGNzCRRj5qgw',
#     'title': 'como é a mente do pai numa final',
#     'description': 'vamos de esquenta pro masters: finalmente saiu a comunicação do nosso quase titulo no kickoff americas. \nSe inscreva no canal e ative o sininho para não perder as notificações de novos vídeos: https://bit.ly/LOUDVALORANT\nTikTok: @loud_valorant\n\nContato comercial: agencia@loud.gg\n\n____________________________________\nValorant é um jogo eletrônico multijogador gratuito para jogar de tiro em primeira pessoa desenvolvido e publicado pela Riot Games. Duas equipes de cinco jogam uma contra a outra, e os jogadores assumem o papel de "agentes" com habilidades únicas.\n\n#VALORANT #LOUD #LOUDValorant',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Fgu5K2IfvRU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Fgu5K2IfvRU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Fgu5K2IfvRU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Fgu5K2IfvRU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Fgu5K2IfvRU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'LOUD VALORANT',
#     'tags': ['LOUD',
#      'VALORANT',
#      'Saadhak',
#      'Less',
#      'Aspas',
#      'pro player',
#      'campeonato',
#      'competitivo',
#      'gameplay',
#      'proplayers',
#      'live',
#      'treinamento',
#      'VCT',
#      'Masters valorant',
#      'valorant loud',
#      'valorant live',
#      'valorant stream',
#      'aspas live',
#      'loud aspas',
#      'valorant clip',
#      'loud less',
#      'loud valorant',
#      'radiante valorant',
#      'loud gameplay valorant',
#      'cortes valorant',
#      'campeonato valorant',
#      'clipes valorant',
#      'valorant clips',
#      'Cauanzin',
#      'Tuyz',
#      'valorant shorts',
#      'loud x sentinels',
#      'loud vs sentinels',
#      'final kickoff',
#      'kickoff americas',
#      'masters madrid',
#      'masters'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'como é a mente do pai numa final',
#      'description': 'vamos de esquenta pro masters: finalmente saiu a comunicação do nosso quase titulo no kickoff americas. \nSe inscreva no canal e ative o sininho para não perder as notificações de novos vídeos: https://bit.ly/LOUDVALORANT\nTikTok: @loud_valorant\n\nContato comercial: agencia@loud.gg\n\n____________________________________\nValorant é um jogo eletrônico multijogador gratuito para jogar de tiro em primeira pessoa desenvolvido e publicado pela Riot Games. Duas equipes de cinco jogam uma contra a outra, e os jogadores assumem o papel de "agentes" com habilidades únicas.\n\n#VALORANT #LOUD #LOUDValorant'},
#     'defaultAudioLanguage': 'pt-BR'},
#    'contentDetails': {'duration': 'PT28M44S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'h7KQRiBBaRdwDzBUQtN6khDeNG8',
#    'id': 'HMoxHtUITIQ',
#    'snippet': {'publishedAt': '2021-09-05T11:43:33Z',
#     'channelId': 'UC_4Jor3Nk1CwGRBqGqvYjtQ',
#     'title': 'Balti - Ya Lili feat. Hamouda (ERS Remix) | Overdrive Stealing [Car Scene]',
#     'description': 'Spotify Playlist ➤ https://spoti.fi/3jdnx3c\n\nTurn on notifications (🔔) to stay updated with new uploads.\nInstagram ➤ https://www.instagram.com/gangstercitylabel\n\n♕ GANGSTER CITY ♕ \nVk: https://vk.com/gangstercitylabel\nTwitter: https://twitter.com/GANGSTERClTY\nTikTok: https://www.tiktok.com/@gangstercitylabel\nTelegram: https://t.me/gangstercitylabel\nSoundcloud: https://soundcloud.com/gangstercitylabel\nFacebook: https://www.facebook.com/gangstercitylabel/\n\n♕ ERS ♕\nhttps://open.spotify.com/artist/6npupyUfzFTmraESmaFzxi?si=PQ0KeqlJTGadn0TDIKw6tQ\nhttps://soundcloud.com/elares-bakytkhan\nhttps://www.instagram.com/ersremix/?hl=rui\n\nFamily:\nVΛVΛ Media: https://bit.ly/35nZYty\nVΛVΛ Music: https://bit.ly/3ktgr5S \nSCREAMING ON THE GLOBE: https://bit.ly/3j2P4l0\nGANGSTER DEEP: https://bit.ly/34r5zAa\nGANGSTER CITY Record Label: https://bit.ly/3jqzhJu\n\n#GANGSTERCITY #VAVAMedia #ScreamingOnTheGlobe #VAVAMusic #GANGSTERDEEP  #CarMusic #BassBoosted\n\n* Contact Email * - contact@gangstercity.net',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HMoxHtUITIQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HMoxHtUITIQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HMoxHtUITIQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/HMoxHtUITIQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/HMoxHtUITIQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'GANGSTER CITY',
#     'tags': ['GANGSTER CITY',
#      'GANGSTER DEEP',
#      'CAR MUSIC',
#      'BASS BOOSTED',
#      'REMIX',
#      'HOUSE MUSIC',
#      'HOUSE',
#      'SLAP HOUSE',
#      'CAR BANGER',
#      'CAR BASS',
#      'BASS MUSIC',
#      'DEEP HOUSE',
#      'G HOUSE',
#      'BRAZZILIAN BASS',
#      'GANG',
#      'TIK TOK',
#      'TIK TOK REMIX',
#      'CLUB MUSIC',
#      'CAR',
#      'CARS',
#      'BOOSTED MUSIC',
#      'VAVAMEDIA',
#      'VAVAMUSIC'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Balti - Ya Lili feat. Hamouda (ERS Remix) | Overdrive Stealing [Car Scene]',
#      'description': 'Spotify Playlist ➤ https://spoti.fi/3jdnx3c\n\nTurn on notifications (🔔) to stay updated with new uploads.\nInstagram ➤ https://www.instagram.com/gangstercitylabel\n\n♕ GANGSTER CITY ♕ \nVk: https://vk.com/gangstercitylabel\nTwitter: https://twitter.com/GANGSTERClTY\nTikTok: https://www.tiktok.com/@gangstercitylabel\nTelegram: https://t.me/gangstercitylabel\nSoundcloud: https://soundcloud.com/gangstercitylabel\nFacebook: https://www.facebook.com/gangstercitylabel/\n\n♕ ERS ♕\nhttps://open.spotify.com/artist/6npupyUfzFTmraESmaFzxi?si=PQ0KeqlJTGadn0TDIKw6tQ\nhttps://soundcloud.com/elares-bakytkhan\nhttps://www.instagram.com/ersremix/?hl=rui\n\nFamily:\nVΛVΛ Media: https://bit.ly/35nZYty\nVΛVΛ Music: https://bit.ly/3ktgr5S \nSCREAMING ON THE GLOBE: https://bit.ly/3j2P4l0\nGANGSTER DEEP: https://bit.ly/34r5zAa\nGANGSTER CITY Record Label: https://bit.ly/3jqzhJu\n\n#GANGSTERCITY #VAVAMedia #ScreamingOnTheGlobe #VAVAMusic #GANGSTERDEEP  #CarMusic #BassBoosted\n\n* Contact Email * - contact@gangstercity.net'}},
#    'contentDetails': {'duration': 'PT3M21S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'b_a1wDX96hZHa1eivngQDnp4bJ0',
#    'id': 'Kt111qLcYtI',
#    'snippet': {'publishedAt': '2022-05-28T14:49:04Z',
#     'channelId': 'UCz2jphL7nCy7vrOGtp2E7rg',
#     'title': 'Balti - Ya Lili feat. Hamouda (Starix & XZEEZ Remix)Overdrive Stealing [Car Scene]',
#     'description': 'Balti - Ya Lili feat. Hamouda (Starix & XZEEZ Remix)Overdrive Stealing [Car Scene]',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Kt111qLcYtI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Kt111qLcYtI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Kt111qLcYtI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Kt111qLcYtI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Kt111qLcYtI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Aleks Born',
#     'tags': ['Balti',
#      'Ya Lili',
#      'Hamouda',
#      'XZEEZ',
#      'Starix',
#      'Overdrive',
#      'Car Scene',
#      'Chase Scene',
#      'GANGSTER DEEP',
#      'CAR MUSIC',
#      'BASS BOOSTED',
#      'REMIX',
#      'HOUSE MUSIC',
#      'HOUSE',
#      'SLAP HOUSE',
#      'CAR BANGER',
#      'CAR BASS',
#      'BASS MUSIC',
#      'DEEP HOUSE',
#      'G HOUSE',
#      'BRAZZILIAN BASS',
#      'GANG',
#      'TIK TOK',
#      'TIK TOK REMIX',
#      'CLUB MUSIC',
#      'CAR',
#      'CARS',
#      'BOOSTED MUSIC',
#      'Aleks Born'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Balti - Ya Lili feat. Hamouda (Starix & XZEEZ Remix)Overdrive Stealing [Car Scene]',
#      'description': 'Balti - Ya Lili feat. Hamouda (Starix & XZEEZ Remix)Overdrive Stealing [Car Scene]'}},
#    'contentDetails': {'duration': 'PT4M58S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'regionRestriction': {'blocked': ['AT', 'DE']},
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '48RoGUG33NOptKefSOEnHE5Also',
#    'id': 'BLlo7rMXI_Q',
#    'snippet': {'publishedAt': '2021-10-10T12:41:41Z',
#     'channelId': 'UC_4Jor3Nk1CwGRBqGqvYjtQ',
#     'title': 'Balti - Ya Lili feat. Hamouda (ERS Remix) Long Version | Overdrive Stealing [Car Scene]',
#     'description': 'Spotify Playlist ➤ https://spoti.fi/3jdnx3c\n\nTurn on notifications (🔔) to stay updated with new uploads.\nInstagram ➤ https://www.instagram.com/gangstercitylabel\n\n♕ GANGSTER CITY ♕ \nShop: https://represent.com/store/gangstercity/\nVk: https://vk.com/gangstercitylabel\nTwitter: https://twitter.com/GANGSTERClTY\nTikTok: https://www.tiktok.com/@gangstercitylabel\nTelegram: https://t.me/gangstercitylabel\nSoundcloud: https://soundcloud.com/gangstercitylabel\nFacebook: https://www.facebook.com/gangstercitylabel/\n\n♕ ERS ♕\nhttps://open.spotify.com/artist/6npupyUfzFTmraESmaFzxi?si=PQ0KeqlJTGadn0TDIKw6tQ\nhttps://soundcloud.com/elares-bakytkhan\nhttps://www.instagram.com/ersremix/?hl=rui\n\nFamily:\nVΛVΛ Media: https://bit.ly/35nZYty\nVΛVΛ Music: https://bit.ly/3ktgr5S \nSCREAMING ON THE GLOBE: https://bit.ly/3j2P4l0\nGANGSTER DEEP: https://bit.ly/34r5zAa\nGANGSTER CITY Record Label: https://bit.ly/3jqzhJu\n\n#GANGSTERCITY #VAVAMedia #ScreamingOnTheGlobe #VAVAMusic #GANGSTERDEEP  #CarMusic #BassBoosted\n\n* Contact Email * - contact@gangstercity.net',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BLlo7rMXI_Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BLlo7rMXI_Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BLlo7rMXI_Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/BLlo7rMXI_Q/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/BLlo7rMXI_Q/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'GANGSTER CITY',
#     'tags': ['GANGSTER CITY',
#      'GANGSTER DEEP',
#      'CAR MUSIC',
#      'BASS BOOSTED',
#      'REMIX',
#      'HOUSE MUSIC',
#      'HOUSE',
#      'SLAP HOUSE',
#      'CAR BANGER',
#      'CAR BASS',
#      'BASS MUSIC',
#      'DEEP HOUSE',
#      'G HOUSE',
#      'BRAZZILIAN BASS',
#      'GANG',
#      'TIK TOK',
#      'TIK TOK REMIX',
#      'CLUB MUSIC',
#      'CAR',
#      'CARS',
#      'BOOSTED MUSIC',
#      'VAVAMEDIA',
#      'VAVAMUSIC'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Balti - Ya Lili feat. Hamouda (ERS Remix) Long Version | Overdrive Stealing [Car Scene]',
#      'description': 'Spotify Playlist ➤ https://spoti.fi/3jdnx3c\n\nTurn on notifications (🔔) to stay updated with new uploads.\nInstagram ➤ https://www.instagram.com/gangstercitylabel\n\n♕ GANGSTER CITY ♕ \nShop: https://represent.com/store/gangstercity/\nVk: https://vk.com/gangstercitylabel\nTwitter: https://twitter.com/GANGSTERClTY\nTikTok: https://www.tiktok.com/@gangstercitylabel\nTelegram: https://t.me/gangstercitylabel\nSoundcloud: https://soundcloud.com/gangstercitylabel\nFacebook: https://www.facebook.com/gangstercitylabel/\n\n♕ ERS ♕\nhttps://open.spotify.com/artist/6npupyUfzFTmraESmaFzxi?si=PQ0KeqlJTGadn0TDIKw6tQ\nhttps://soundcloud.com/elares-bakytkhan\nhttps://www.instagram.com/ersremix/?hl=rui\n\nFamily:\nVΛVΛ Media: https://bit.ly/35nZYty\nVΛVΛ Music: https://bit.ly/3ktgr5S \nSCREAMING ON THE GLOBE: https://bit.ly/3j2P4l0\nGANGSTER DEEP: https://bit.ly/34r5zAa\nGANGSTER CITY Record Label: https://bit.ly/3jqzhJu\n\n#GANGSTERCITY #VAVAMedia #ScreamingOnTheGlobe #VAVAMusic #GANGSTERDEEP  #CarMusic #BassBoosted\n\n* Contact Email * - contact@gangstercity.net'}},
#    'contentDetails': {'duration': 'PT6M42S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'BPsVOaELzc0eqXJZSCcMnZEfAUw',
#    'id': 'MgbngiiwihM',
#    'snippet': {'publishedAt': '2019-04-25T18:18:28Z',
#     'channelId': 'UCCOSYITWQHRSUxvlQ4_PSCg',
#     'title': 'Team Sonic Racing Overdrive Complete',
#     'description': "The full, combined animation of Team Sonic Racing: Overdrive! \n\nPre-Order now Team Sonic Racing now at: https://bit.ly/2IFbIOz\n\nSpecial thanks to Tyson Hesse, Neko Productions, the SEGA production team and everyone involved in this project! Following the great success of Mania Adventures, we couldn't wait to show our fans a Modern Sonic animation, and TSR was the perfect opportunity. All the people in the credits worked remarkably hard over many months, so please let them know what you thought in the comments here on the video!",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MgbngiiwihM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MgbngiiwihM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MgbngiiwihM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/MgbngiiwihM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/MgbngiiwihM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Sonic the Hedgehog',
#     'tags': ['sonic',
#      'sonic the hedgehog',
#      'team sonic racing',
#      'team sonic racing overdrive',
#      'team sonic racing overdrive complete',
#      'sonic movie',
#      'knuckles the echidna',
#      'rouge the bat',
#      'tails the fox',
#      'dr. eggman',
#      'TSR',
#      'TSRO',
#      'TSR Overdrive',
#      'sonic animation',
#      'animated sonic'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Team Sonic Racing Overdrive Complete',
#      'description': "The full, combined animation of Team Sonic Racing: Overdrive! \n\nPre-Order now Team Sonic Racing now at: https://bit.ly/2IFbIOz\n\nSpecial thanks to Tyson Hesse, Neko Productions, the SEGA production team and everyone involved in this project! Following the great success of Mania Adventures, we couldn't wait to show our fans a Modern Sonic animation, and TSR was the perfect opportunity. All the people in the credits worked remarkably hard over many months, so please let them know what you thought in the comments here on the video!"},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT9M13S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '2kqaKmAzgHmsVLLcADtx557anSE',
#    'id': 'Rt25H3OqT5g',
#    'snippet': {'publishedAt': '2014-05-08T16:41:53Z',
#     'channelId': 'UCmV2SO-wJJ6FLmkxe7by4pA',
#     'title': 'Oliver Heldens X Becky Hill - Gecko (Overdrive) [Radio Edit]',
#     'description': 'Download / Stream Gecko (Overdrive) here: https://ffrr.lnk.to/Gecko\n\nGecko (Overdrive) by Oliver Heldens & Becky Hill was released on June 20th 2014 by FFRR Records.\n\nFollow FFRR:\nhttps://www.facebook.com/FFRRecords\u200b\u200b\u200b\u200b\u200b\nhttps://twitter.com/FFRRecords\u200b\u200b\u200b\u200b\u200b\nhttps://www.instagram.com/ffrrecords/\u200b\u200b\u200b\u200b\n\nFollow Becky Hill:\nhttps://www.facebook.com/Beckyhillofficial/\nhttps://twitter.com/BeckyHill\nhttps://www.instagram.com/beckyhill/\n\nFollow Oliver Heldens:\nhttps://www.facebook.com/OliverHeldens/\nhttps://twitter.com/oliverheldens\nhttps://www.instagram.com/oliverheldens\nhttps://soundcloud.com/oliverheldens\n\nFFRR was founded in 1986. The label has brought countless culturally important records across the dance music spectrum over the years including Orbital, Armand Van Helden, Salt ‘N’ Pepa, Lil Louis, Goldie to name but a few. \nWe continue to build on that heritage with new & exciting cutting-edge music. Since the beginning of 2020, FFRR has enjoyed success with Diplo & SIDEPIECE’s “On My Mind”, Alan Fitzpatrick vs Patrice Rushen’s “Haven’t You Heard” and Obskür’s “Bayside”. They have also welcomed artists such as Eats Everything, Sam Gellaitry and Sonny Fodera to the FFRR family.\nOur mission is to release Music That Moves You.\n\n#Overdrive #BeckyHill #OliverHeldens #FFRR #Gecko',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Rt25H3OqT5g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Rt25H3OqT5g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Rt25H3OqT5g/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Rt25H3OqT5g/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Rt25H3OqT5g/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'FFRR',
#     'tags': ['Radio Edit',
#      'Becky Hill',
#      'Gecko',
#      'Oliver heldens',
#      'Spinning records',
#      'Musical Freedom',
#      'MNEK',
#      'MNEK (Musical Artist)',
#      'Zane Lowe',
#      'Hottest Record',
#      'Pete Tong (Musical Artist)',
#      'FFRR Records (Organization)',
#      'Parlophone (Record Label)',
#      'Dance-pop (Musical Genre)',
#      'Dance music',
#      'House Music (Musical Genre)',
#      'Ready for you love',
#      'Keizsa',
#      'Sigma',
#      'Nobody to love',
#      'Mr Probz',
#      'cash cash',
#      'Calvin harris',
#      'Rudimental',
#      'Rudimental (Musical Group)',
#      'Wilkinson',
#      'Afterglow',
#      'Electronic Music (Musical Genre)',
#      'Radio 1'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Oliver Heldens X Becky Hill - Gecko (Overdrive) [Radio Edit]',
#      'description': 'Download / Stream Gecko (Overdrive) here: https://ffrr.lnk.to/Gecko\n\nGecko (Overdrive) by Oliver Heldens & Becky Hill was released on June 20th 2014 by FFRR Records.\n\nFollow FFRR:\nhttps://www.facebook.com/FFRRecords\u200b\u200b\u200b\u200b\u200b\nhttps://twitter.com/FFRRecords\u200b\u200b\u200b\u200b\u200b\nhttps://www.instagram.com/ffrrecords/\u200b\u200b\u200b\u200b\n\nFollow Becky Hill:\nhttps://www.facebook.com/Beckyhillofficial/\nhttps://twitter.com/BeckyHill\nhttps://www.instagram.com/beckyhill/\n\nFollow Oliver Heldens:\nhttps://www.facebook.com/OliverHeldens/\nhttps://twitter.com/oliverheldens\nhttps://www.instagram.com/oliverheldens\nhttps://soundcloud.com/oliverheldens\n\nFFRR was founded in 1986. The label has brought countless culturally important records across the dance music spectrum over the years including Orbital, Armand Van Helden, Salt ‘N’ Pepa, Lil Louis, Goldie to name but a few. \nWe continue to build on that heritage with new & exciting cutting-edge music. Since the beginning of 2020, FFRR has enjoyed success with Diplo & SIDEPIECE’s “On My Mind”, Alan Fitzpatrick vs Patrice Rushen’s “Haven’t You Heard” and Obskür’s “Bayside”. They have also welcomed artists such as Eats Everything, Sam Gellaitry and Sonny Fodera to the FFRR family.\nOur mission is to release Music That Moves You.\n\n#Overdrive #BeckyHill #OliverHeldens #FFRR #Gecko'}},
#    'contentDetails': {'duration': 'PT2M46S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'NLiF_8EFizMikU8LoyDM070gwkg',
#    'id': 'pYCRA2TX8Lo',
#    'snippet': {'publishedAt': '2018-11-16T07:15:00Z',
#     'channelId': 'UC1ciY6kR3yj3kaKZ6R7ewAg',
#     'title': 'Bandar Mama Aur Kele | Hindi Rhymes for Children | Infobells',
#     'description': 'This Hindi Rhymes for Children featuring Bandar Mama demonstrates how one should eat carefully, not take big bites and be messy.\n\nFor More details visit: www.infobells.com\n\nCheck out our Android Apps :\n\nhttps://play.google.com/store/search?q=infobells&c=apps',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pYCRA2TX8Lo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pYCRA2TX8Lo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pYCRA2TX8Lo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/pYCRA2TX8Lo/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Infobells - Hindi',
#     'tags': ['Hindi rhymes for children',
#      'Hindi rhymes',
#      'Hindi rhymes for kids',
#      'kids rhymes Hindi',
#      'baby songs Hindi',
#      'Hindi rhymes nursery',
#      'Hindi rhymes collection',
#      'rhymes in Hindi',
#      'bal geet',
#      'Hindi rhymes playlist',
#      'Hindi kids rhymes',
#      'Hindi baby songs',
#      'infobells',
#      'infobells rhymes',
#      'Hindi lullabies',
#      'bal geet in hindi',
#      'bachon ke songs hindi',
#      'bandar mama',
#      'bandar mama kele khaya',
#      'bandar mama rhyme',
#      'bandar mama pehan pajama',
#      'monkey rhyme',
#      'hindi monkey rhyme',
#      'monkey song hindi'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Bandar Mama Aur Kele | Hindi Rhymes for Children | Infobells',
#      'description': 'This Hindi Rhymes for Children featuring Bandar Mama demonstrates how one should eat carefully, not take big bites and be messy.\n\nFor More details visit: www.infobells.com\n\nCheck out our Android Apps :\n\nhttps://play.google.com/store/search?q=infobells&c=apps'}},
#    'contentDetails': {'duration': 'PT2M13S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '29JaPwQsTt8tHPf4MNPF5fQ1sAw',
#    'id': 'ObCzCnZIe8w',
#    'snippet': {'publishedAt': '2021-10-12T11:00:11Z',
#     'channelId': 'UCth6n_FHj9XBqGNuuVgcizA',
#     'title': 'Farmer BiBi obedient take care of her friends',
#     'description': 'Farmer BiBi obedient take care of her friends\n@ Help our lovely animals with Paypal \n paypal.me/Animalshome123\nThank you\n#babymonkey #Animalshome',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ObCzCnZIe8w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ObCzCnZIe8w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ObCzCnZIe8w/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/ObCzCnZIe8w/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/ObCzCnZIe8w/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': ' Animals_Home',
#     'tags': ['Farmer BiBi obedient take care of her friends'],
#     'categoryId': '15',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Farmer BiBi obedient take care of her friends',
#      'description': 'Farmer BiBi obedient take care of her friends\n@ Help our lovely animals with Paypal \n paypal.me/Animalshome123\nThank you\n#babymonkey #Animalshome'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT9M17S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'sMYapGZSzzkB42U_yy61afEGbwc',
#    'id': 'KbaiHpW6M68',
#    'snippet': {'publishedAt': '2022-01-07T09:56:42Z',
#     'channelId': 'UCth6n_FHj9XBqGNuuVgcizA',
#     'title': 'BiBi helps dad take care of baby monkey OBi',
#     'description': 'BiBi helps dad take care of baby monkey OBi\n@ Help our lovely animals with Paypal \n paypal.me/Animalshome123\nThank you\n#babymonkey #Animalshome',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KbaiHpW6M68/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KbaiHpW6M68/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KbaiHpW6M68/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/KbaiHpW6M68/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/KbaiHpW6M68/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': ' Animals_Home',
#     'tags': ['BiBi helps dad take care of baby monkey OBi'],
#     'categoryId': '15',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'BiBi helps dad take care of baby monkey OBi',
#      'description': 'BiBi helps dad take care of baby monkey OBi\n@ Help our lovely animals with Paypal \n paypal.me/Animalshome123\nThank you\n#babymonkey #Animalshome'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT4M39S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'wQbcmMCkAjpg19CkmfcdJIoB3rc',
#    'id': 'wS1BdGbhp-g',
#    'snippet': {'publishedAt': '2022-02-26T10:37:34Z',
#     'channelId': 'UCKDasR7mtBEO0awPpWOBrhA',
#     'title': 'Smart Bim Bim flies a helicopter to harvest fruit to make noodles',
#     'description': 'Smart Bim Bim flies a helicopter to harvest fruit to make noodles\n#BabyMonkeyAnimal #Animal #bimbimonkey',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wS1BdGbhp-g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wS1BdGbhp-g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wS1BdGbhp-g/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/wS1BdGbhp-g/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/wS1BdGbhp-g/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Baby Monkey Animal',
#     'tags': ['Smart Bim Bim flies a helicopter to harvest fruit to make noodles'],
#     'categoryId': '15',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Smart Bim Bim flies a helicopter to harvest fruit to make noodles',
#      'description': 'Smart Bim Bim flies a helicopter to harvest fruit to make noodles\n#BabyMonkeyAnimal #Animal #bimbimonkey'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT31M59S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'ncj3ITpuJ_mAUUuUj9kLID8rwxc',
#    'id': 'AaTT4FAQN2M',
#    'snippet': {'publishedAt': '2023-05-16T14:30:03Z',
#     'channelId': 'UCzDqT_4aq2SQe9u2fuZsvsw',
#     'title': 'FREE FIRE ✧ VS ✧ PUBG 🔥🥵 ✓ #freefire #shorts',
#     'description': 'FREE FIRE ✧ VS ✧ PUBG 🔥🥵 ✓ \nfree fire #shorts \n@TotalGaming093 @factomuch_HARI \n\n--------------------------------------------\nDisclaimer - If Any Contact Owner Has Some Issues With My Any Video Please Direct Message Me On @Gmail And Will Remove My Videos But please Don\'t Copyright Claim/Strike Our Video Bicoz There Are Lost Of My Hardwork To Create A One Videos.\n\nContact us:-\nmouryarohit99092@gmail.com\n\nDisclaimer\n\nCopyright Disclaimer Under Section 107 of the Copyright Act 1976, allowance is made for "fair use" for purposes such as criticism, comment, news re porting, teaching, scholarship, and research. Fair use is a use permitted by copyright statute that might otherwise be infringing. Non-profit, educational or personal use tips the balance in favor of fair use.\n--------------------------------------------------------------\nThanks for Watching My Video.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AaTT4FAQN2M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AaTT4FAQN2M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AaTT4FAQN2M/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/AaTT4FAQN2M/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/AaTT4FAQN2M/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'FactoMuch',
#     'tags': ['free fire vs pubg',
#      'free fire challenge video',
#      'free fire shorts',
#      'free fire trending video',
#      'free fire new update',
#      'so kaise ho factomuch ki family',
#      'sabka baap free fire',
#      'free fire new trend',
#      'ff vs pubg'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'FREE FIRE ✧ VS ✧ PUBG 🔥🥵 ✓ #freefire #shorts',
#      'description': 'FREE FIRE ✧ VS ✧ PUBG 🔥🥵 ✓ \nfree fire #shorts \n@TotalGaming093 @factomuch_HARI \n\n--------------------------------------------\nDisclaimer - If Any Contact Owner Has Some Issues With My Any Video Please Direct Message Me On @Gmail And Will Remove My Videos But please Don\'t Copyright Claim/Strike Our Video Bicoz There Are Lost Of My Hardwork To Create A One Videos.\n\nContact us:-\nmouryarohit99092@gmail.com\n\nDisclaimer\n\nCopyright Disclaimer Under Section 107 of the Copyright Act 1976, allowance is made for "fair use" for purposes such as criticism, comment, news re porting, teaching, scholarship, and research. Fair use is a use permitted by copyright statute that might otherwise be infringing. Non-profit, educational or personal use tips the balance in favor of fair use.\n--------------------------------------------------------------\nThanks for Watching My Video.'},
#     'defaultAudioLanguage': 'hi'},
#    'contentDetails': {'duration': 'PT33S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '_cwlqj4pEzXzycX7NscBjSHfVbI',
#    'id': 'iP_9ZcWdsjg',
#    'snippet': {'publishedAt': '2023-05-21T22:17:27Z',
#     'channelId': 'UCGbHu0bRpEe1w1UhNJYS67A',
#     'title': 'VIAJAMOS A LA PLAYA: fares vino para competir y yo me vine a divertir😳',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iP_9ZcWdsjg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iP_9ZcWdsjg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iP_9ZcWdsjg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/iP_9ZcWdsjg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/iP_9ZcWdsjg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'janin al chair',
#     'categoryId': '23',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es-419',
#     'localized': {'title': 'VIAJAMOS A LA PLAYA: fares vino para competir y yo me vine a divertir😳',
#      'description': ''},
#     'defaultAudioLanguage': 'es-419'},
#    'contentDetails': {'duration': 'PT59S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'RanQdb-XaaGIrbNC7oEphua0Xks',
#    'id': '2_xx-sdw7kE',
#    'snippet': {'publishedAt': '2022-04-19T22:44:09Z',
#     'channelId': 'UCZs0WwC0Dn_noiQE2BHSTKg',
#     'title': 'CUANDO TE QUIEREN COMPETIR CON POP ITS 🤣',
#     'description': 'Ya sabes que hacer cuando tu compañero de clases quiere competir 😎 jajaja',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2_xx-sdw7kE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2_xx-sdw7kE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2_xx-sdw7kE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/2_xx-sdw7kE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/2_xx-sdw7kE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alejo Igoa',
#     'tags': ['shorts',
#      'tiktok',
#      'tik tok',
#      'alejo igoa',
#      'alejoigoa',
#      '24 horas'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es',
#     'localized': {'title': 'CUANDO TE QUIEREN COMPETIR CON POP ITS 🤣',
# ...
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT2H6S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '0WtuRR6Z8MUhSDNGJ3gsi54gg_4',
#    'id': 'PJgLHBJ86Nc',
#    'snippet': {'publishedAt': '2024-03-12T16:52:02Z',
#     'channelId': 'UCZICzaOoKDJVPxDaD_IB_GQ',
#     'title': "Unveiling Coconut's Role in Rahu Remedy",
#     'description': 'Discover the unique and powerful role of coconuts in mitigating the adverse effects of Rahu in our latest short video. Often seen as a formidable planet in astrology, Rahu’s influence can bring about significant challenges and disruptions. However, the humble coconut holds the key to pacifying Rahu and restoring balance to your life. This video explores the symbolic significance of coconuts in astrological remedies, detailing how they can be used in rituals to soothe Rahu’s tumultuous energy. Whether you’re facing obstacles in your career, personal life, or seeking spiritual growth, learn how the act of offering coconuts can serve as an effective remedy to align Rahu’s influence positively. Join us as we unveil the simplicity and power of this traditional practice, offering you a straightforward solution to complex astrological challenges. Embrace the potential for harmony and peace by understanding coconut’s role in Rahu remedies. Be sure to like, share, and subscribe for more insights into harnessing the benefits of astrology in your everyday life.\n\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCZICzaOoKDJVPxDaD_IB_GQ/join',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PJgLHBJ86Nc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PJgLHBJ86Nc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PJgLHBJ86Nc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/PJgLHBJ86Nc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/PJgLHBJ86Nc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Astro India',
#     'tags': ['Rahu',
#      'astrology',
#      'fast rahu mantra',
#      'lord rahu mantra',
#      'rahu dasha',
#      'rahu dosh',
#      'rahu effects',
#      'rahu effects in life',
#      'rahu in astrology',
#      'rahu in life',
#      'rahu ka asar',
#      'rahu kaal',
#      'rahu ke upay',
#      'rahu ke upaye',
#      'rahu mahadasha',
#      'rahu mantra fast',
#      'rahu puja',
#      'rahu remedies',
#      'vedic astrology',
#      'राहु बीज मंत्र'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': "Unveiling Coconut's Role in Rahu Remedy",
#      'description': 'Discover the unique and powerful role of coconuts in mitigating the adverse effects of Rahu in our latest short video. Often seen as a formidable planet in astrology, Rahu’s influence can bring about significant challenges and disruptions. However, the humble coconut holds the key to pacifying Rahu and restoring balance to your life. This video explores the symbolic significance of coconuts in astrological remedies, detailing how they can be used in rituals to soothe Rahu’s tumultuous energy. Whether you’re facing obstacles in your career, personal life, or seeking spiritual growth, learn how the act of offering coconuts can serve as an effective remedy to align Rahu’s influence positively. Join us as we unveil the simplicity and power of this traditional practice, offering you a straightforward solution to complex astrological challenges. Embrace the potential for harmony and peace by understanding coconut’s role in Rahu remedies. Be sure to like, share, and subscribe for more insights into harnessing the benefits of astrology in your everyday life.\n\n\nJoin this channel to get access to perks:\nhttps://www.youtube.com/channel/UCZICzaOoKDJVPxDaD_IB_GQ/join'},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT51S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'yRiL7cyCdoznQC4FgXO7dBLZxY4',
#    'id': 'WBqio4UcrZk',
#    'snippet': {'publishedAt': '2024-03-12T16:25:35Z',
#     'channelId': 'UC8yuaNBUMgttmcteh6W84OA',
#     'title': 'Modern India The Last Lap & Role of Different Nationalists | UPSC IAS Hindi History | By Kinshuk Sir',
#     'description': "Modern India The Last Lap & Role of Different Nationalists | UPSC IAS Hindi History | By Kinshuk Sir #kgsias #upsc #upscmotivation #upscias #medievalindia  #medievalindianhistory \n\nWelcome to KGS IAS - Your Gateway to Success in State PCS and UPSC Exams! 🏆\nAt KGS IAS, we are proud to be a part of Khan Sir Patna's Khan Global Studies, a renowned name in the competitive exam arena. Join us as we embark on a journey of knowledge, guidance, and excellence, and let's explore why KGS IAS is your ideal choice.\n🔹 What We Offer:\n📌 Holistic Syllabus Coverage: Our meticulously crafted courses ensure that you are well-prepared for every aspect of State PCS and UPSC exams. From Prelims to Mains, and the Personality Test, we've got your back.\n\n📌 Distinguished Faculty: Our team of experienced educators, including some former civil servants, brings their extensive knowledge and experience to your doorstep. They are not just teachers but mentors who guide you every step of the way.\n\n📌 Updated Study Materials: Stay ahead with the most current and relevant study materials, including the latest government policies, exam trends, and essential resources.\n\n📌 Rigorous Mock Tests: We believe in the power of practice. Regular mock tests and in-depth evaluation help you assess your progress and focus on areas that need improvement.\n\n📌 Personalized Guidance: Every student is unique, and we understand that. Our mentors provide personalized guidance to cater to your specific needs and goals.\n\n📌 Current Affairs and News Analysis: Staying updated with the latest news and current affairs is crucial for competitive exams. We provide comprehensive coverage and in-depth analysis to keep you informed and ready.\n\n🔹 Why You Should Choose KGS IAS:\n🌟 Proven Track Record: Our history of producing successful candidates in State PCS and UPSC exams is a testament to our dedication to turning your dreams into accomplishments.\n\n🌟 Comprehensive Approach: We don't just teach; we nurture your analytical thinking, writing skills, and personality development. We strive to mold you into not just a candidate but a well-rounded civil servant.\n\n🌟 Community Support: Join a dynamic community of aspirants who share your dreams and goals. Connect, collaborate, and support each other on this challenging yet rewarding journey.\n\n🌟 Student-Centric Approach: At KGS IAS, your success is our mission. We are committed to leaving no stone unturned in helping you achieve your goals.\n\nJoin us on this path of knowledge and transformation. Subscribe to KGS IAS, a part of Khan Sir Patna's Khan Global Studies, and let's begin this incredible journey together!\n\nJoin our Social Media for more updates and information.\nFacebook link -  https://www.facebook.com/livekgs\n\nInstagram link  -  https://www.instagram.com/khanglobalstudies_official\n\nTwitter link  -  https://twitter.com/kgs_live\n\nTelegram link - https://t.me/KGS_IAS \n\nLinkedIn -  https://www.linkedin.com/company/khan-global-studies/\n\nPinterest   -    https://in.pinterest.com/khanglobalstudies/\n\nQuora  -   https://www.quora.com/profile/Khan-\n\nFor more information on Khan Global Studies courses, call us at: 8757354880 or Download our App - https://kgs.yt/3A9zLe",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WBqio4UcrZk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WBqio4UcrZk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WBqio4UcrZk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/WBqio4UcrZk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/WBqio4UcrZk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'KGS IAS Hindi',
#     'tags': ['kgs ias hindi',
#      'kgs',
#      'upsc ias',
#      'upsc',
#      'medieval india',
#      'medieval indian history',
#      'medieval history',
#      'medieval history of india',
#      'indian history',
#      'complete medieval history of india',
#      'complete medieval indian history',
#      'medieval india upsc',
#      'early medieval india',
#      'medieval india in english',
#      'indian medieval history',
#      'medieval indian history mcq',
#      'history gk',
#      'history of india',
#      'modern indian history',
#      'modern history of india',
#      'Medieval India PYQs Discussion',
#      'medieval india pyq upsc',
#      'history'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Modern India The Last Lap & Role of Different Nationalists | UPSC IAS Hindi History | By Kinshuk Sir',
#      'description': "Modern India The Last Lap & Role of Different Nationalists | UPSC IAS Hindi History | By Kinshuk Sir #kgsias #upsc #upscmotivation #upscias #medievalindia  #medievalindianhistory \n\nWelcome to KGS IAS - Your Gateway to Success in State PCS and UPSC Exams! 🏆\nAt KGS IAS, we are proud to be a part of Khan Sir Patna's Khan Global Studies, a renowned name in the competitive exam arena. Join us as we embark on a journey of knowledge, guidance, and excellence, and let's explore why KGS IAS is your ideal choice.\n🔹 What We Offer:\n📌 Holistic Syllabus Coverage: Our meticulously crafted courses ensure that you are well-prepared for every aspect of State PCS and UPSC exams. From Prelims to Mains, and the Personality Test, we've got your back.\n\n📌 Distinguished Faculty: Our team of experienced educators, including some former civil servants, brings their extensive knowledge and experience to your doorstep. They are not just teachers but mentors who guide you every step of the way.\n\n📌 Updated Study Materials: Stay ahead with the most current and relevant study materials, including the latest government policies, exam trends, and essential resources.\n\n📌 Rigorous Mock Tests: We believe in the power of practice. Regular mock tests and in-depth evaluation help you assess your progress and focus on areas that need improvement.\n\n📌 Personalized Guidance: Every student is unique, and we understand that. Our mentors provide personalized guidance to cater to your specific needs and goals.\n\n📌 Current Affairs and News Analysis: Staying updated with the latest news and current affairs is crucial for competitive exams. We provide comprehensive coverage and in-depth analysis to keep you informed and ready.\n\n🔹 Why You Should Choose KGS IAS:\n🌟 Proven Track Record: Our history of producing successful candidates in State PCS and UPSC exams is a testament to our dedication to turning your dreams into accomplishments.\n\n🌟 Comprehensive Approach: We don't just teach; we nurture your analytical thinking, writing skills, and personality development. We strive to mold you into not just a candidate but a well-rounded civil servant.\n\n🌟 Community Support: Join a dynamic community of aspirants who share your dreams and goals. Connect, collaborate, and support each other on this challenging yet rewarding journey.\n\n🌟 Student-Centric Approach: At KGS IAS, your success is our mission. We are committed to leaving no stone unturned in helping you achieve your goals.\n\nJoin us on this path of knowledge and transformation. Subscribe to KGS IAS, a part of Khan Sir Patna's Khan Global Studies, and let's begin this incredible journey together!\n\nJoin our Social Media for more updates and information.\nFacebook link -  https://www.facebook.com/livekgs\n\nInstagram link  -  https://www.instagram.com/khanglobalstudies_official\n\nTwitter link  -  https://twitter.com/kgs_live\n\nTelegram link - https://t.me/KGS_IAS \n\nLinkedIn -  https://www.linkedin.com/company/khan-global-studies/\n\nPinterest   -    https://in.pinterest.com/khanglobalstudies/\n\nQuora  -   https://www.quora.com/profile/Khan-\n\nFor more information on Khan Global Studies courses, call us at: 8757354880 or Download our App - https://kgs.yt/3A9zLe"}},
#    'contentDetails': {'duration': 'PT45M49S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '86V56655XO0AXChcBc-l7Xf7PRk',
#    'id': 'sMEQB7Okmi0',
#    'snippet': {'publishedAt': '2016-01-29T17:55:54Z',
#     'channelId': 'UCSxsi2uNwmewgetIeveu8pQ',
#     'title': 'Strategy video game',
#     'description': 'If you find our videos helpful you can support us by buying something from amazon.\nhttps://www.amazon.com/?tag=wiki-audio-20\n\nStrategy video game\r\n\n Strategy video game is a video game genre that focuses on skillful thinking and planning to achieve victory.It emphasizes strategic, tactical, and sometimes logistical challenges.\n\n-Video is targeted to blind users\n\nAttribution:\nArticle text available under CC-BY-SA\nimage source in video\n\n\nhttps://www.youtube.com/watch?v=sMEQB7Okmi0',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sMEQB7Okmi0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sMEQB7Okmi0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sMEQB7Okmi0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/sMEQB7Okmi0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/sMEQB7Okmi0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'WikiAudio',
#     'tags': ['Strategy video game'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Strategy video game',
#      'description': 'If you find our videos helpful you can support us by buying something from amazon.\nhttps://www.amazon.com/?tag=wiki-audio-20\n\nStrategy video game\r\n\n Strategy video game is a video game genre that focuses on skillful thinking and planning to achieve victory.It emphasizes strategic, tactical, and sometimes logistical challenges.\n\n-Video is targeted to blind users\n\nAttribution:\nArticle text available under CC-BY-SA\nimage source in video\n\n\nhttps://www.youtube.com/watch?v=sMEQB7Okmi0'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT17M43S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'}}]}
